# %%
import os

import dotenv
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio

# %%
dotenv.load_dotenv('../.env')
data_path = os.getenv('DATA_PATH') + '/raw'

# %%
# get data dirs
data_dirs = [os.path.join(data_path, d) for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d))]

# %%
records = []
for file_path in data_dirs:
    files = [os.path.join(file_path, f) for f in os.listdir(file_path) if os.path.isfile(os.path.join(file_path, f))]
    slug = file_path.split('/')[-1]
    records.append(dict(
        slug=slug,
        img=False,
        desc=False,
        tweet=False,
        ts=False
    ))
    for file in files:
        file = file.split('/')[-1]
        if file.endswith('.png'):
            records[-1]['img'] = True
        if file.endswith('.txt'):
            records[-1]['desc'] = True
        if file.endswith('.json'):
            records[-1]['ts'] = True

# %%
# Out:
# [{'slug': 'meridian-art-blocks-playground',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cyberkongz-babies',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cryptodickbutts',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'veefriends-series-2',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'Decentraland',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cyberkongz-vx',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'killabears',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'curio-cards',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'meebits', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'memories-of-qilin-art-blocks-curated',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'the-potatoz',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'degods', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'asm-aifa-genesis',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'hv-mtl-nft',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'bored-ape-kennel-club',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cyberkongz-genesis',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'terraforms-by-mathcastles',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'onchainmonkey',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'doodles', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'a-kid-called-beast',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'murakami-flowers',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'pudgy-penguins',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'youtherealmvp',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'live-like-a-cat-nekonoyouniikiru',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'dodgers-mlb-crypto',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'beeple-genesis-collection',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'world-of-women',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cryptoninja-partners',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'renga', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'veefriends', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': '0n1-force', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'autoglyphs', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'azuki', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'damien-hirst-the-currency',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'io-imaginary-ones',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'friendship-bracelets-by-alexis-andre',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'nft-worlds', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'eulerbeats-genesis-original',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'checks-vv-edition',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'beeple-spring-summer-collection',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'bored_ape_chemistry_club',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'the_sandbox',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'the-singularity',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'fluf-world', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'etheria', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'clonex', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'beeple-everydays',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'neo-tokyo-part-4-land-deeds',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cryptopunks',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'kanpai-pandas',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'bored-ape-yacht-club',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'nakamigos', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'creepz-genesis',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cool-cats', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'qql-mint-pass',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'invisible-friends',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'sappy-seals',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'elevated-deconstructions-art-blocks-curated',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'genesis-braindrops',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'gazers', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'opepen-edition-nft',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'v1-cryptopunks-wrapped',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'ringers-art-blocks-curated',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'chromie-squiggle-art-blocks-curated',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'milady', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'space-doodles',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'forgotten-runes-wizards-cult',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'otherdeed', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'digidaigaku',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'renga-black-box',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'proof-moonbirds',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'archetype-art-blocks-curated',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'max-pain-and-frens-by-xcopy',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'mutant-ape-yacht-club',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'mocaverse', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'lil-pudgys',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'pixelmon-generation-1',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'deafbeef', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'valhalla', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'grifters-by-xcopy',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cyberbrokers',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'fidenza-art-blocks-curated',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'rektguy', 'img': True, 'desc': False, 'tweet': False, 'ts': True},
#  {'slug': 'adidas-originals-into-the-metaverse-phase-1-and-2',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'thecaptainz',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'the-eternal-pump',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'neo-tokyo-identities',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'incomplete-control-by-tyler-hobbs',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'mfers', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'loomlocknft',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'cryptoadz', 'img': True, 'desc': True, 'tweet': False, 'ts': True},
#  {'slug': 'rtfkt-egg-animus',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'anticyclone-art-blocks-curated',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'the-memes-by-6529',
#   'img': True,
#   'desc': False,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'beanz-official',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True},
#  {'slug': 'proof-collective',
#   'img': True,
#   'desc': True,
#   'tweet': False,
#   'ts': True}]
